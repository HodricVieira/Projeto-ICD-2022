# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from random import randint

# %%
data = pd.read_csv("telecom_users.csv")
data
# Out:
#       Codigo   IDCliente     Genero  Aposentado Casado Dependentes  \
# 0       1869  7010-BRBUU  Masculino           0    Sim         Sim
# 1       4528  9688-YGXVR   Feminino           0    Nao         Nao
# 2       6344  9286-DOJGF   Feminino           1    Sim         Nao
# 3       6739  6994-KERXL  Masculino           0    Nao         Nao
# 4        432  2181-UAESM  Masculino           0    Nao         Nao
# ...      ...         ...        ...         ...    ...         ...
# 5981    3772  0684-AOSIH  Masculino           0    Sim         Nao
# 5982    5191  5982-PSMKW   Feminino           0    Sim         Sim
# 5983    5226  8044-BGWPI  Masculino           0    Sim         Sim
# 5984    5390  7450-NWRTR  Masculino           1    Nao         Nao
# 5985     860  4795-UXVCJ  Masculino           0    Nao         Nao
#
#       MesesComoCliente ServicoTelefone MultiplasLinhas ServicoInternet  ...  \
# 0                   72             Sim             Sim             Nao  ...
# 1                   44             Sim             Nao           Fibra  ...
# 2                   38             Sim             Sim           Fibra  ...
# 3                    4             Sim             Nao             DSL  ...
# 4                    2             Sim             Nao             DSL  ...
# ...                ...             ...             ...             ...  ...
# 5981                 1             Sim             Nao           Fibra  ...
# 5982                23             Sim             Sim             DSL  ...
# 5983                12             Sim             Nao             Nao  ...
# 5984                12             Sim             Sim           Fibra  ...
# 5985                26             Sim             Nao             Nao  ...
#
#      ProtecaoEquipamento ServicoSuporteTecnico ServicoStreamingTV  \
# 0            SemInternet           SemInternet        SemInternet
# 1                    Sim                   Nao                Sim
# 2                    Nao                   Nao                Nao
# 3                    Nao                   Nao                Nao
# 4                    Sim                   Nao                Nao
# ...                  ...                   ...                ...
# 5981                 Nao                   Nao                Sim
# 5982                 Sim                   Sim                Sim
# 5983         SemInternet           SemInternet        SemInternet
# 5984                 Sim                   Nao                Sim
# 5985         SemInternet           SemInternet        SemInternet
#
#      ServicoFilmes TipoContrato FaturaDigital    FormaPagamento ValorMensal  \
# 0      SemInternet       2 anos           Nao     CartaoCredito       24.10
# 1              Nao       Mensal           Sim     CartaoCredito       88.15
# 2              Nao       Mensal           Sim  DebitoAutomatico       74.95
# 3              Sim       Mensal           Sim  BoletoEletronico       55.90
# 4              Nao       Mensal           Nao  BoletoEletronico       53.45
# ...            ...          ...           ...               ...         ...
# 5981           Sim       Mensal           Sim  BoletoEletronico       95.00
# 5982           Sim       2 anos           Sim     CartaoCredito       91.10
# 5983   SemInternet       Mensal           Sim  BoletoEletronico       21.15
# 5984           Sim       Mensal           Sim  BoletoEletronico       99.45
# 5985   SemInternet        Anual           Nao     CartaoCredito       19.80
#
#      TotalGasto  Churn
# 0       1734.65    Nao
# 1       3973.20    Nao
# 2       2869.85    Sim
# 3        238.50    Nao
# 4        119.50    Nao
# ...         ...    ...
# 5981      95.00    Sim
# 5982    2198.30    Nao
# 5983     306.05    Nao
# 5984    1200.15    Sim
# 5985     457.30    Nao
#
# [5986 rows x 22 columns]

# %%
data_corr = data[['Codigo','MesesComoCliente', 'Dependentes','TipoContrato','FormaPagamento', 'ValorMensal','TotalGasto', 'Churn']]
for linha in data_corr.index:
    # DEPENDENTES
    if data_corr.loc[linha, 'Dependentes'] == "Sim":
        data_corr.loc[linha, 'Dependentes'] = 2
    else:
        data_corr.loc[linha, 'Dependentes'] = 1
    
    # tipo contrato
    if data_corr.loc[linha, 'TipoContrato'] =="2 anos":
        data_corr.loc[linha, 'TipoContrato'] = 2
    elif data_corr.loc[linha, 'TipoContrato'] == "anual":
        data_corr.loc[linha, 'TipoContrato'] = 1
    else:
        data_corr.loc[linha, 'TipoContrato'] = 3
    
    # Forma de pagamento
    if data_corr.loc[linha, 'FormaPagamento'] == "CartaoCredito":
        data_corr.loc[linha, 'FormaPagamento'] = 1
    elif data_corr.loc[linha, 'FormaPagamento'] == "DebitoAutomatico":
        data_corr.loc[linha, 'FormaPagamento'] = 2
    elif data_corr.loc[linha, 'FormaPagamento'] ==  "BoletoEletronico":
        data_corr.loc[linha, 'FormaPagamento'] = 3
    else:
        data_corr.loc[linha, 'FormaPagamento'] = 4
    
    #Churn
    if data_corr.loc[linha, 'Churn'] == "Sim":
        data_corr.loc[linha, 'Churn'] = 1
    else:
        data_corr.loc[linha, 'Churn'] = 0
# Out:
# C:\Users\ivoar\AppData\Local\Temp\ipykernel_9640\287003906.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_corr.loc[linha, 'codigo2'] = randint(1, 10000)

# %%
data_corr
# Out:
#       Codigo  MesesComoCliente Dependentes TipoContrato FormaPagamento  \
# 0       1869                72           2            2              1
# 1       4528                44           1            3              1
# 2       6344                38           1            3              2
# 3       6739                 4           1            3              3
# 4        432                 2           1            3              3
# ...      ...               ...         ...          ...            ...
# 5981    3772                 1           1            3              3
# 5982    5191                23           2            2              1
# 5983    5226                12           2            3              3
# 5984    5390                12           1            3              3
# 5985     860                26           1            3              1
#
#       ValorMensal  TotalGasto Churn  codigo2
# 0           24.10     1734.65     0   5140.0
# 1           88.15     3973.20     0   4078.0
# 2           74.95     2869.85     1   1008.0
# 3           55.90      238.50     0   4639.0
# 4           53.45      119.50     0   7908.0
# ...           ...         ...   ...      ...
# 5981        95.00       95.00     1   3549.0
# 5982        91.10     2198.30     0   2175.0
# 5983        21.15      306.05     0   8647.0
# 5984        99.45     1200.15     1    398.0
# 5985        19.80      457.30     0   8180.0
#
# [5986 rows x 9 columns]

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(data_corr[["Churn", "Dependentes", "TipoContrato", "FormaPagamento"]])
# Out:
# KMeans(n_clusters=5)

# %%
sns.scatterplot(x=data_corr["MesesComoCliente"], y=data_corr["ValorMensal"], hue=kmeans.labels_)
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
data_corr["Grupo"] = kmeans.labels_
# Out:
# C:\Users\ivoar\AppData\Local\Temp\ipykernel_9640\2799549941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_corr["Grupo"] = kmeans.labels_

# %% [markdown]
# ## Grupo 0 e suas correlações

# %%
dados = data_corr[data_corr["Grupo"] == 0]
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Churn"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["TipoContrato"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
dados = data_corr[data_corr["Grupo"] == 0]
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Dependentes"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
dados = data_corr[data_corr["Grupo"] == 0]
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["FormaPagamento"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %% [markdown]
# ## grupo 1 e sua correlações

# %%
dados = data_corr[data_corr["Grupo"] == 1]
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Churn"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["TipoContrato"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Dependentes"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["FormaPagamento"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %% [markdown]
# ## grupo 2 e suas correlações

# %%
dados = data_corr[data_corr["Grupo"] == 2]
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Churn"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["TipoContrato"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Dependentes"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["FormaPagamento"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %% [markdown]
# ## grupo 3 e suas correlações

# %%
dados = data_corr[data_corr["Grupo"] == 3]
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Churn"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["TipoContrato"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["Dependentes"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>

# %%
sns.scatterplot(x=dados["MesesComoCliente"], y=dados["ValorMensal"], hue=dados["FormaPagamento"])
# Out:
# <AxesSubplot:xlabel='MesesComoCliente', ylabel='ValorMensal'>
