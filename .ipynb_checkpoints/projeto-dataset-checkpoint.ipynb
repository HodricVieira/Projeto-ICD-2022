# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("telecom_users.csv")
data
# Out:
#       Codigo   IDCliente     Genero  Aposentado Casado Dependentes  \
# 0       1869  7010-BRBUU  Masculino           0    Sim         Sim
# 1       4528  9688-YGXVR   Feminino           0    Nao         Nao
# 2       6344  9286-DOJGF   Feminino           1    Sim         Nao
# 3       6739  6994-KERXL  Masculino           0    Nao         Nao
# 4        432  2181-UAESM  Masculino           0    Nao         Nao
# ...      ...         ...        ...         ...    ...         ...
# 5981    3772  0684-AOSIH  Masculino           0    Sim         Nao
# 5982    5191  5982-PSMKW   Feminino           0    Sim         Sim
# 5983    5226  8044-BGWPI  Masculino           0    Sim         Sim
# 5984    5390  7450-NWRTR  Masculino           1    Nao         Nao
# 5985     860  4795-UXVCJ  Masculino           0    Nao         Nao
#
#       MesesComoCliente ServicoTelefone MultiplasLinhas ServicoInternet  ...  \
# 0                   72             Sim             Sim             Nao  ...
# 1                   44             Sim             Nao           Fibra  ...
# 2                   38             Sim             Sim           Fibra  ...
# 3                    4             Sim             Nao             DSL  ...
# 4                    2             Sim             Nao             DSL  ...
# ...                ...             ...             ...             ...  ...
# 5981                 1             Sim             Nao           Fibra  ...
# 5982                23             Sim             Sim             DSL  ...
# 5983                12             Sim             Nao             Nao  ...
# 5984                12             Sim             Sim           Fibra  ...
# 5985                26             Sim             Nao             Nao  ...
#
#      ProtecaoEquipamento ServicoSuporteTecnico ServicoStreamingTV  \
# 0            SemInternet           SemInternet        SemInternet
# 1                    Sim                   Nao                Sim
# 2                    Nao                   Nao                Nao
# 3                    Nao                   Nao                Nao
# 4                    Sim                   Nao                Nao
# ...                  ...                   ...                ...
# 5981                 Nao                   Nao                Sim
# 5982                 Sim                   Sim                Sim
# 5983         SemInternet           SemInternet        SemInternet
# 5984                 Sim                   Nao                Sim
# 5985         SemInternet           SemInternet        SemInternet
#
#      ServicoFilmes TipoContrato FaturaDigital    FormaPagamento ValorMensal  \
# 0      SemInternet       2 anos           Nao     CartaoCredito       24.10
# 1              Nao       Mensal           Sim     CartaoCredito       88.15
# 2              Nao       Mensal           Sim  DebitoAutomatico       74.95
# 3              Sim       Mensal           Sim  BoletoEletronico       55.90
# 4              Nao       Mensal           Nao  BoletoEletronico       53.45
# ...            ...          ...           ...               ...         ...
# 5981           Sim       Mensal           Sim  BoletoEletronico       95.00
# 5982           Sim       2 anos           Sim     CartaoCredito       91.10
# 5983   SemInternet       Mensal           Sim  BoletoEletronico       21.15
# 5984           Sim       Mensal           Sim  BoletoEletronico       99.45
# 5985   SemInternet        Anual           Nao     CartaoCredito       19.80
#
#      TotalGasto  Churn
# 0       1734.65    Nao
# 1       3973.20    Nao
# 2       2869.85    Sim
# 3        238.50    Nao
# 4        119.50    Nao
# ...         ...    ...
# 5981      95.00    Sim
# 5982    2198.30    Nao
# 5983     306.05    Nao
# 5984    1200.15    Sim
# 5985     457.30    Nao
#
# [5986 rows x 22 columns]

# %%
#media dos valores numericos
valoresdata = data[["MesesComoCliente","ValorMensal","TotalGasto"]]
valoresdata.mean()
# Out:
# MesesComoCliente      32.468760
# ValorMensal           64.802213
# TotalGasto          2298.060617
# dtype: float64

# %%
#Mediana dos valores numericos
valoresdata.median()
# Out:
# MesesComoCliente      29.00
# ValorMensal           70.40
# TotalGasto          1412.15
# dtype: float64

# %%
#Modas
moda = data.mode(dropna=False)
moda
# Out:
#       Codigo   IDCliente     Genero  Aposentado Casado Dependentes  \
# 0          0  0002-ORFBO  Masculino         0.0    Nao         Nao
# 1          1  0003-MKNFE        NaN         NaN    NaN         NaN
# 2          2  0004-TLHLJ        NaN         NaN    NaN         NaN
# 3          3  0011-IGKFF        NaN         NaN    NaN         NaN
# 4          4  0013-EXCHZ        NaN         NaN    NaN         NaN
# ...      ...         ...        ...         ...    ...         ...
# 5981    7038  9986-BONCE        NaN         NaN    NaN         NaN
# 5982    7039  9987-LUTYD        NaN         NaN    NaN         NaN
# 5983    7040  9992-RRAMN        NaN         NaN    NaN         NaN
# 5984    7041  9992-UJOEL        NaN         NaN    NaN         NaN
# 5985    7042  9993-LHIEB        NaN         NaN    NaN         NaN
#
#       MesesComoCliente ServicoTelefone MultiplasLinhas ServicoInternet  ...  \
# 0                  1.0             Sim             Nao           Fibra  ...
# 1                  NaN             NaN             NaN             NaN  ...
# 2                  NaN             NaN             NaN             NaN  ...
# 3                  NaN             NaN             NaN             NaN  ...
# 4                  NaN             NaN             NaN             NaN  ...
# ...                ...             ...             ...             ...  ...
# 5981               NaN             NaN             NaN             NaN  ...
# 5982               NaN             NaN             NaN             NaN  ...
# 5983               NaN             NaN             NaN             NaN  ...
# 5984               NaN             NaN             NaN             NaN  ...
# 5985               NaN             NaN             NaN             NaN  ...
#
#      ProtecaoEquipamento ServicoSuporteTecnico ServicoStreamingTV  \
# 0                    Nao                   Nao                Nao
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 5981                 NaN                   NaN                NaN
# 5982                 NaN                   NaN                NaN
# 5983                 NaN                   NaN                NaN
# 5984                 NaN                   NaN                NaN
# 5985                 NaN                   NaN                NaN
#
#      ServicoFilmes TipoContrato FaturaDigital    FormaPagamento ValorMensal  \
# 0              Nao       Mensal           Sim  BoletoEletronico       20.05
# 1              NaN          NaN           NaN               NaN         NaN
# 2              NaN          NaN           NaN               NaN         NaN
# 3              NaN          NaN           NaN               NaN         NaN
# 4              NaN          NaN           NaN               NaN         NaN
# ...            ...          ...           ...               ...         ...
# 5981           NaN          NaN           NaN               NaN         NaN
# 5982           NaN          NaN           NaN               NaN         NaN
# 5983           NaN          NaN           NaN               NaN         NaN
# 5984           NaN          NaN           NaN               NaN         NaN
# 5985           NaN          NaN           NaN               NaN         NaN
#
#      TotalGasto  Churn
# 0          20.2    Nao
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN
# ...         ...    ...
# 5981        NaN    NaN
# 5982        NaN    NaN
# 5983        NaN    NaN
# 5984        NaN    NaN
# 5985        NaN    NaN
#
# [5986 rows x 22 columns]

# %%
data.boxplot(column=["TotalGasto"])
plt.show()

# %%
data.boxplot(column=["ValorMensal"])
plt.show()

# %%
data.boxplot(column=["MesesComoCliente"])
plt.show()

# %%
#variancia
print(data["TotalGasto"].var())
print(data["MesesComoCliente"].var())
print(data["ValorMensal"].var())
# Out:
# 5171654.364593108
# 601.0534098918083
# 906.8952544981033

# %%
#Desvio Absoluto
print(data["TotalGasto"].mad())
print(data["MesesComoCliente"].mad())
print(data["ValorMensal"].mad())
# Out:
# 1908.6029405523702
# 21.82108325149818
# 26.263588438732587

# %%
#Desvio Padrão
print(data["TotalGasto"].std())
print(data["MesesComoCliente"].std())
print(data["ValorMensal"].std())
# Out:
# 2274.1271654402067
# 24.51639063752673
# 30.114701633888114

# %%
#correlação
corrmat = data.corr()
  
f, ax = plt.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
# Out:
# <AxesSubplot:>
